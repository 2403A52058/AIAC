# %% [markdown]
# <a href="https://colab.research.google.com/github/2403A52058/AIAC/blob/main/Lab_7_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task #1 – Syntax Error in Conditionals  ![Screenshot 2025-09-16 132408.png](data:image/png;base64,...)
#
# prompt:
# a = 10
# if a = 10:
#     print("Equal")
#   Syntax Error in Conditionals

# %%
a = 10
if a == 10:
    print("Equal")

# %% [markdown]
#  Explanation:
#
#  The syntax error is in the line if a = 10:. The assignment operator (=) is used instead of the comparison operator (==) in the conditional statement. It should be corrected to if a == 10: to perform an equality check.

# %% [markdown]
# OBSERVATION:
# The syntax error occurs in the line if a = 10:. This is because the assignment operator (=) is used instead of the comparison operator (==) within a conditional statement. The correct way to check for equality in a conditional statement is to use the double equals sign.

# %% [markdown]
# Task #2 – Loop Off-By-One Error ![Screenshot 2025-09-16 133348.png](data:image/png;base64,...)
# prompt:
#
# the above code is Loop Off-By-One Error fix it

# %%
def sum_upto_n(n):
    total = 0
    for i in range(1, n + 1):  # Corrected line
        total += i
    return total

# %% [markdown]
# Explanation:
#
# The off-by-one error occurs because range(1, n) in Python generates a sequence of numbers starting from 1 up to, but not including, n. Therefore, the loop will sum numbers from 1 to n-1, excluding n itself. If the intent is to sum numbers up to and including n, the range() function should be range(1, n + 1).
# For example, if n is 5, range(1, 5) will produce [1, 2, 3, 4], and total will be 1+2+3+4 = 10. To include 5, range(1, 5 + 1) or range(1, 6) should be used, which produces [1, 2, 3, 4, 5], resulting in a total of 1+2+3+4+5 = 15

# %% [markdown]
# OBSERVATION:
#
# 1)for i in range(1, n): This loop iterates, assigning i values from 1 up to n-1
#
#
# 2)total += i Inside the loop, this line adds the current value of i to the total variable.
#
#
# 3)return total After the loop, this line returns the final calculated total sum (from 1 to n-1)

# %% [markdown]
# TASK 03:
# ![image.png](data:image/png;base64,...)
#
# Error: AttributeError
#
# PROMPT:identify the missing method and correct the code

# %%
class User:
    def __init__(self, name):
        self.name = name

    def getName(self):
        return self.name

u = User("Alice")
print(u.getName())

# %% [markdown]
# EXPLANATION:
#
# 1)A User class is defined with a constructor (__init__) that initializes a name attribute and a getName method to return it.
#
# 2)An instance u of the User class is created, passing "Alice" as the name.
#
#
# 3)The getName method is called on the u object, and the returned name ("Alice") is printed to the console.

# %% [markdown]
# OBSERVATION:
#
# 1)The User class initializes with a name attribute and includes a getName method to retrieve it.
#
# 2)Calling u.getName() returns "Alice", which is printed to the console.

# %% [markdown]
# TASK 04:Incorrect Class Attribute Initialization
#
#
# ![image.png](data:image/png;base64,...)
#
# PROMPT:
# identify missing self and initialize attributes properly.

# %%
class Car:
    def __init__(self, color):
        self.color = color

    def start(self):
        print(f"{self.color} Car started")

mycar = Car("Red")
mycar.start()

# %% [markdown]
# EXPLANATION:
#
# This code defines a Car class with a color attribute. The constructor __init__ initializes the car's color. The start method prints a message including the car's color. An instance of the Car class with "Red" color is created and its start method is called.

# %% [markdown]
# OBSERVATION:
#
# A Car class is defined with an __init__ method that takes color as a parameter.
#
# The color is assigned to an instance variable self.color.
#
# The class has a start method that prints a message including the car's color.
#
# An instance mycar of the Car class is created with "Red" as the color.
#
# Calling mycar.start() prints "Red Car started" to the console.

# %% [markdown]
# TASK 05: Conditional Logic Error in Grading System
#
# ![image.png](data:image/png;base64,...)
#
# prompt:Detect illogical grading and correct the grade levels in the above code

# %%
def grade_student(score):
    if score >= 70:
        return "A"
    elif score >= 40:
        return "B"
    else:
        return "C"

# %% [markdown]
# EXPLANATION:
#
# The function grade_student takes a numeric score as input.
#
# If the score is 70 or above, it returns the grade "A".
#
# If the score is between 40 and 69 (inclusive), it returns "B".
#
# For any score below 40, it returns the grade "C".

# %% [markdown]
# OBSERVATION:
#
# The function assigns grades based on the score ranges: 70+ is "A", 40–69 is "B", and below 40 is "C".
#
# It uses conditional statements (if, elif, else) to determine the grade.
#
# The appropriate grade is returned as a string depending on the input score.
